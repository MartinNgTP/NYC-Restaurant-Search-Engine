# %% [markdown]
# Data Source:
# * NYC Open Data API for restaurants data
# * https://dev.socrata.com/foundry/data.cityofnewyork.us/43nn-pn8j
# * NewsAPI for articles (json files)
# * https://newsapi.org/
#
# Technologies:
# 1. **Request API** from NewsAPI to get "food" related articles & NYC Open Data API for restaurants data
# 2. Store articles data and restaurants data in **MongoDB**
# 3. **Flask** to get user input cuisine and zipcode, output restaurants and articles.
#
# Cannot be run on Google Collab because localhost

# %% [markdown]
# # NYC Restaurants data

# %% [markdown]
# Import data from Socrata Open Data API, give it a minute to load.

# %%
#pip install sodapy

# %%
# Ignore warning
from sodapy import Socrata
import pandas as pd

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("43nn-pn8j", limit=300000)

# Convert to pandas DataFrame
restaurants = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Number of rows
len(restaurants)
# Out:
# 224563

# %%
restaurants.head()
# Out:
#       camis                    dba       boro building            street  \
# 0  50105039        CHINA CHEF CHEN   Brooklyn     1073   FLATBUSH AVENUE
# 1  50111234  AIRPORT BAGELS & DELI     Queens     8420      ASTORIA BLVD
# 2  50109894            Tokyo Sushi  Manhattan      151  RIVINGTON STREET
# 3  50032701                    KUU  Manhattan       20       JOHN STREET
# 4  41232125          VELVET LOUNGE   Brooklyn      174          BROADWAY
#
#   zipcode       phone cuisine_description          inspection_date  \
# 0   11226  7182878173             Chinese  2023-01-09T00:00:00.000
# 1   11370  6468069605            American  2022-02-08T00:00:00.000
# 2   10002  6468820152            Japanese  2023-02-14T00:00:00.000
# 3   10038  2125717177            Japanese  2022-03-29T00:00:00.000
# 4   11211  7183024427            American  2022-02-16T00:00:00.000
#
#                                             action  ...  \
# 0  Violations were cited in the following area(s).  ...
# 1  Violations were cited in the following area(s).  ...
# 2  Violations were cited in the following area(s).  ...
# 3  Violations were cited in the following area(s).  ...
# 4  Violations were cited in the following area(s).  ...
#
#                record_date                                inspection_type  \
# 0  2024-04-17T06:00:13.000               Cycle Inspection / Re-inspection
# 1  2024-04-17T06:00:13.000  Pre-permit (Operational) / Initial Inspection
# 2  2024-04-17T06:00:13.000               Cycle Inspection / Re-inspection
# 3  2024-04-17T06:00:13.000          Cycle Inspection / Initial Inspection
# 4  2024-04-17T06:00:13.000          Cycle Inspection / Initial Inspection
#
#           latitude         longitude community_board council_district  \
# 0  40.644454931217   -73.95795139689             314               40
# 1  40.764612087724  -73.884845497109             403               22
# 2  40.719240393784  -73.985645741014             103               01
# 3  40.709837370946  -74.008876810465             101               01
# 4  40.710010026465  -73.962602595341             301               34
#
#   census_tract      bin         bbl   nta
# 0       079200  3118908  3051650087  BK95
# 1       032900  4024027  4010960022  QN28
# 2       001402  1004172  1003480015  MN28
# 3       001502  1001104  1000650022  MN25
# 4       054900  3059532  3021320020  BK73
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Clean data

# %% [markdown]
# * Columns dba(restaurant name), cuisine_description, and zipcode contain missing values
# * Lowercase cuisine_description for easier search
# * Duplicate restaurant records, drop duplicates

# %%
# Ignore warning
columns_to_check = ['dba', 'cuisine_description', 'zipcode']
df = restaurants.dropna(subset=columns_to_check)

df['zipcode'] = df['zipcode'].astype(int).astype(str)
df.loc[:,'cuisine_description'] = df['cuisine_description'].str.lower()

restaurants_cleaned = df.drop_duplicates(subset=['dba'], keep='first')  #Keeps only the first occurrence
# Out:
# /var/folders/pf/pdyz_nzx4mz21xl07fjfgymh0000gn/T/ipykernel_55760/2950411719.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['zipcode'] = df['zipcode'].astype(int).astype(str)

# %%
# Number of restaurants
len(restaurants_cleaned)
# Out:
# 20769

# %%
restaurants_cleaned.head()
# Out:
#       camis                    dba       boro building            street  \
# 0  50105039        CHINA CHEF CHEN   Brooklyn     1073   FLATBUSH AVENUE
# 1  50111234  AIRPORT BAGELS & DELI     Queens     8420      ASTORIA BLVD
# 2  50109894            Tokyo Sushi  Manhattan      151  RIVINGTON STREET
# 3  50032701                    KUU  Manhattan       20       JOHN STREET
# 4  41232125          VELVET LOUNGE   Brooklyn      174          BROADWAY
#
#   zipcode       phone cuisine_description          inspection_date  \
# 0   11226  7182878173             chinese  2023-01-09T00:00:00.000
# 1   11370  6468069605            american  2022-02-08T00:00:00.000
# 2   10002  6468820152            japanese  2023-02-14T00:00:00.000
# 3   10038  2125717177            japanese  2022-03-29T00:00:00.000
# 4   11211  7183024427            american  2022-02-16T00:00:00.000
#
#                                             action  ...  \
# 0  Violations were cited in the following area(s).  ...
# 1  Violations were cited in the following area(s).  ...
# 2  Violations were cited in the following area(s).  ...
# 3  Violations were cited in the following area(s).  ...
# 4  Violations were cited in the following area(s).  ...
#
#                record_date                                inspection_type  \
# 0  2024-04-17T06:00:13.000               Cycle Inspection / Re-inspection
# 1  2024-04-17T06:00:13.000  Pre-permit (Operational) / Initial Inspection
# 2  2024-04-17T06:00:13.000               Cycle Inspection / Re-inspection
# 3  2024-04-17T06:00:13.000          Cycle Inspection / Initial Inspection
# 4  2024-04-17T06:00:13.000          Cycle Inspection / Initial Inspection
#
#           latitude         longitude community_board council_district  \
# 0  40.644454931217   -73.95795139689             314               40
# 1  40.764612087724  -73.884845497109             403               22
# 2  40.719240393784  -73.985645741014             103               01
# 3  40.709837370946  -74.008876810465             101               01
# 4  40.710010026465  -73.962602595341             301               34
#
#   census_tract      bin         bbl   nta
# 0       079200  3118908  3051650087  BK95
# 1       032900  4024027  4010960022  QN28
# 2       001402  1004172  1003480015  MN28
# 3       001502  1001104  1000650022  MN25
# 4       054900  3059532  3021320020  BK73
#
# [5 rows x 26 columns]

# %% [markdown]
# # Articles:

# %% [markdown]
# Since this API permits request as far back as one month ago, calculate date of one month ago

# %%
#pip install python-dateutil

# %%
import datetime
from dateutil.relativedelta import relativedelta

# Get one month ago's date
today_date = datetime.date.today()
one_month_ago = today_date - relativedelta(months=1)
one_month_ago_str = one_month_ago.strftime('%Y-%m-%d')

# %%
import requests

# Keywords for now: dining, cuisine, restaurant, recipe. 
# Add more or modify to improve search results.
url = (
    f'https://newsapi.org/v2/everything?'
    f'q=(dining OR cuisine OR restaurant OR recipe)&'
    f'from={one_month_ago_str}&'
       'apiKey=7152e173864048d6934a8df325418c66')

response = requests.get(url)
data = response.json()
articles = data.get('articles', [])

# %%
data
# Out:
# {'status': 'ok',
#  'totalResults': 20911,
#  'articles': [{'source': {'id': 'fox-news', 'name': 'Fox News'},
#    'author': 'Kurt Knutsson, CyberGuy Report',
#    'title': 'Restaurant combines an amusement ride with unforgettable fine dining',
#    'description': 'Eatrenalin is a restaurant in Germany with a Floating Chair innovation that makes the 17,000-square-foot venue feel like an amusement park.',
#    'url': 'https://www.foxnews.com/tech/restaurant-combines-amusement-ride-with-unforgettable-fine-dining',
#    'urlToImage': 'https://static.foxnews.com/foxnews.com/content/uploads/2024/04/2-The-roaming-restaurant-experience-that-lets-you-go-from-room-to-room-without-ever-leaving-your-seat.jpg',
#    'publishedAt': '2024-04-10T10:00:16Z',
#    'content': "Ready for an amazing restaurant experience that'll take your taste buds on a wild ride as you move from one incredible room to the next? Sounds like an amusement park experience, right?\r\nIf you thoug… [+3983 chars]"},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': 'Time',
#    'title': 'Brooks Headley',
#    'description': 'Before he was a chef, Brooks Headley was a drummer. To follow his journey from hardcore-punk clubs to fine-dining kitchens to the forefront of culinary innovation is to reconsider not just how we view cooking, but also how we all might better express ourselve…',
#    'url': 'https://time.com/6964708/brooks-headley/',
#    'urlToImage': 'https://api.time.com/wp-content/uploads/2024/04/time-100-2024-brooks-hadley.jpg?quality=85',
#    'publishedAt': '2024-04-17T11:11:12Z',
#    'content': 'Before he was a chef, Brooks Headley was a drummer. To follow his journey from hardcore-punk clubs to fine-dining kitchens to the forefront of culinary innovation is to reconsider not just how we vie… [+892 chars]'},
#   {'source': {'id': None, 'name': 'The Atlantic'},
#    'author': 'Isabel Fattal',
#    'title': 'What Restaurant Behavior Says About a Person',
#    'description': 'Dining out can be an opportunity to see a human being at their hungriest, their showiest, or their most human.',
#    'url': 'https://www.theatlantic.com/newsletters/archive/2024/03/the-everyday-indignities-of-dining-out/677933/?utm_source=feed',
#    'urlToImage': None,
#    'publishedAt': '2024-03-30T12:00:00Z',
#    'content': 'This is an edition of The Wonder Reader, a newsletter in which our editors recommend a set of stories to spark your curiosity and fill you with delight. Sign up here to get it every Saturday morning.… [+2006 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Marielle Descalsota',
#    'title': "A 35-year-old French chef just earned 3 Michelin stars — and he's not even the youngest chef to reach the milestone",
#    'description': 'French media touted Fabien Ferré as the youngest three-Michelin-starred chef. But several chefs had clinched the award even younger.',
#    'url': 'https://www.businessinsider.com/fabien-ferre-not-youngest-chef-to-earn-three-michelin-stars-2024-3',
#    'urlToImage': 'https://i.insider.com/65f909cc895d822030321f24?width=1200&format=jpeg',
#    'publishedAt': '2024-03-20T03:00:13Z',
#    'content': 'Fabien Ferré is one of the youngest chefs ever to attain three Michelin stars.GUILLAUME SOUVANT/Getty Images\r\n<ul><li>Fabien Ferré is the executive chef of La Table du Castellet, a three-Michelin-sta… [+2880 chars]'},
#   {'source': {'id': None, 'name': 'Dezeen'},
#    'author': 'Kate Mazade',
#    'title': 'Pearce+ creates temporary sub-zero restaurant in Canada',
#    'description': 'UK architecture studio Pearce+ and Canadian designer Joe Kalturnyk have created a temporary inflatable restaurant for subzero temperatures in Winnipeg, Canada. The barrel-vaulted restaurant has space for 48 guests dining in temperatures as low as -30 degrees …',
#    'url': 'https://www.dezeen.com/2024/03/27/pearce-sub-zero-pop-up-restaurant-canada/',
#    'urlToImage': 'https://static.dezeen.com/uploads/2024/03/raw-almond-restaurant-pearce-hero-600x600.jpg',
#    'publishedAt': '2024-03-27T18:00:45Z',
#    'content': 'UK architecture studio Pearce+ and Canadian designer Joe Kalturnyk have created a temporary inflatable restaurant for subzero temperatures in Winnipeg, Canada.\r\nThe barrel-vaulted restaurant has spac… [+4007 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Why did all the Little Chefs disappear?',
#    'description': 'At its height, Little Chef had 439 restaurants across the UK but just two decades later they were all gone.',
#    'url': 'https://www.bbc.co.uk/news/business-68796980',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/E9C3/production/_133134895_pdc_0350markham.jpg',
#    'publishedAt': '2024-04-12T23:34:17Z',
#    'content': 'With 439 restaurants on major routes across the UK, Little Chef once enjoyed a near monopoly on roadside dining. So, why did the restaurant chain disappear? \r\nMany of us have fond memories of childho… [+6579 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "Fast-food franchisees in California fear they'll lose customers to Chili's and Applebee's as prices soar over $20 wage",
#    'description': "Fast-food franchisees in California worry diners may flock to Chili's and Applebee's to avoid price hikes introduced to offset the $20 fast-food wage.",
#    'url': 'https://www.businessinsider.com/fast-food-california-expensive-diners-could-switch-to-chilis-applebees-2024-4',
#    'urlToImage': 'https://i.insider.com/660e93213f923f7dab047eda?width=1200&format=jpeg',
#    'publishedAt': '2024-04-14T21:42:01Z',
#    'content': "Fast-food franchisees in California are raising prices to offset the state's new $20 wage. Paul Weaver/SOPA Images/LightRocket via Getty Images\r\n<ul><li>Fast-food franchisees in California fear diner… [+5124 chars]"},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "Olive Garden's owner says lower-income customers are cutting back while richer diners are eating out more",
#    'description': 'Darden Restaurants\' CEO said that sales from lower-income customers were "much lower" than at the same time last year.',
#    'url': 'https://www.businessinsider.com/darden-restaurants-olive-garden-longhorn-steakhouse-lower-income-diners-trend-2024-3',
#    'urlToImage': 'https://i.insider.com/65fd6c6d895d822030333718?width=1200&format=jpeg',
#    'publishedAt': '2024-03-22T11:53:03Z',
#    'content': 'Scott Olson/Getty Images\r\n<ul><li>Darden says lower-income diners are cutting back on its brands while high earners are visiting more.</li><li>Darden, which owns Olive Garden and\xa0LongHorn Steakhouse,… [+3521 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "'I can't charge $20 for a Happy Meal': McDonald's franchisee responds to California's new fast-food worker wages",
#    'description': 'Restaurant owners have been looking at ways to offset the bigger paychecks, from raising prices to cutting back on labor.',
#    'url': 'https://www.businessinsider.com/mcdonalds-franchisee-on-raising-prices-to-cover-california-minimum-wage-2024-4',
#    'urlToImage': 'https://i.insider.com/660bd96316bde8d4ead46ca6?width=1200&format=jpeg',
#    'publishedAt': '2024-04-02T11:22:59Z',
#    'content': "McDonald's.Allen J. Schaben/Los Angeles Times via Getty Images\r\n<ul><li>A McDonald's franchisee who's raised prices because of California's $20 minimum wage is worried about scaring off diners.</li><… [+3245 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Kenneth Niemeyer',
#    'title': 'The rapid rise and fall of ghost kitchens',
#    'description': "Major brands like Wendy's and Kroger are scaling back ghost kitchen operations due to stress and customer complaints, The New York Times reported.",
#    'url': 'https://www.businessinsider.com/ghost-kitchens-decline-quality-virtual-brands-mrbeast-burger-2024-4',
#    'urlToImage': 'https://i.insider.com/661adb9d3f923f7dab07bce4?width=1200&format=jpeg',
#    'publishedAt': '2024-04-14T12:44:28Z',
#    'content': "Many virtual food brands relied on ghost kitchens to produce their delivery-only products. But it hasn't taken off like some expected.Getty Images\r\n<ul><li>Restaurants are scaling back 'ghost kitchen… [+3854 chars]"},
#   {'source': {'id': None, 'name': 'Marginalrevolution.com'},
#    'author': 'Tyler Cowen',
#    'title': 'San Francisco dining',
#    'description': 'Dwarkesh brought me to the very good Sizzling Pot King, 139 8th St, San Francisco, genuine Hunan food and yes I have been to Changsha.\xa0 Don’t walk there though, take an Uber or better yet a Waymo.\xa0 Dwarkesh was kind enough to call me one for the trip back to …',
#    'url': 'https://marginalrevolution.com/marginalrevolution/2024/03/san-francisco-dining-2.html',
#    'urlToImage': 'https://marginalrevolution.com/wp-content/uploads/2016/10/MR-logo-thumbnail.png',
#    'publishedAt': '2024-03-26T17:52:40Z',
#    'content': 'Dwarkesh brought me to the very good Sizzling Pot King, 139 8th St, San Francisco, genuine Hunan food and yes I have been to Changsha.\xa0 Don’t walk there though, take an Uber or better yet a Waymo.\xa0 D… [+406 chars]'},
#   {'source': {'id': None, 'name': 'The New Yorker'},
#    'author': 'Helen Rosner',
#    'title': 'Restaurant Review: Corima',
#    'description': 'Corima offers attention-grabbing tortillas, Japanese flourishes, and an ambitious tasting menu that hasn’t quite found its stride.',
#    'url': 'https://www.newyorker.com/culture/the-food-scene/mexican-ish-fine-dining-with-detours-corima',
#    'urlToImage': 'https://media.newyorker.com/photos/661574fb11a61221f3ca740a/16:9/w_1280,c_limit/r44115.jpg',
#    'publishedAt': '2024-04-14T10:00:00Z',
#    'content': 'Corimas kitchen has a special way of coaxing depth out of ingredients. Many of the most successful dishes are slow-cooked, soft-textured. A bowl of ayacote beans, firm-fleshed with satiny insides, co… [+3622 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Linette Lopez',
#    'title': 'New York City is entering a gaudy new Gilded Age',
#    'description': "After a decade of minimalist chic, Wall Street's favorite restaurants are suddenly louder and more extravagant than ever.",
#    'url': 'https://www.businessinsider.com/new-york-city-gaudy-gilded-age-restaurants-bars-wall-street-2024-4',
#    'urlToImage': 'https://i.insider.com/660434f13f923f7dab01a558?width=1200&format=jpeg',
#    'publishedAt': '2024-04-04T09:26:01Z',
#    'content': 'New York City dining has embraced a new Gilded Age with luxurious, maximalist restaurants with decadent ingredients as international as the city.Carl Godfrey for BI\r\nThe bars and restaurants that put… [+14554 chars]'},
#   {'source': {'id': None, 'name': 'Design-milk.com'},
#    'author': 'Vy Yang',
#    'title': 'Alex Proba Explores Italian Cuisine With Concrete Collaborative',
#    'description': 'Alex Proba embraces a muted palette and mid-century modern elegance in her new tile collection with Concrete Collaborative inspired by Italian cuisine.',
#    'url': 'https://design-milk.com/alex-proba-explores-italian-cuisine-with-concrete-collaborative/',
#    'urlToImage': 'https://design-milk.com/images/2024/03/alex-proba-concrete-collaborative-aurora-tile-collection-3.jpg',
#    'publishedAt': '2024-03-19T16:00:14Z',
#    'content': 'While most people associate Alex Proba with her signature art style, which is characterized by vibrant colors and playful shapes, her friends and loved ones are reminded of her when they see somethin… [+2563 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "People buy more steak in restaurants when beef prices are high because they're scared to cook it at home and mess up, restaurant boss says",
#    'description': "Customers worry that they could be taking a risk if they cook steak at home when it's expensive, Darden's CFO said.",
#    'url': 'https://www.businessinsider.com/beef-expensive-diners-buy-more-steak-at-restaurants-dining-darden-2024-3',
#    'urlToImage': 'https://i.insider.com/65fd821a2417f97b87ce5583?width=1200&format=jpeg',
#    'publishedAt': '2024-03-22T14:47:56Z',
#    'content': "10'000 Hours/Getty Images\r\n<ul><li>When beef prices are high, customers buy more steak at restaurants, Darden's CFO said.</li><li>It's because customers worry about taking a risk if they cook steak a… [+2231 chars]"},
#   {'source': {'id': None, 'name': 'Thekitchn.com'},
#    'author': 'Christine Gallary',
#    'title': 'SPONSORED POST: Crispy Rice with California Avocado and Tuna Tartare',
#    'description': 'When you think of what makes California cuisine so special and delicious, two of the biggest features are high-quality seafood and fresh produce. One such combination, fresh tuna and sustainably grown California Avocado, magically becomes a vibrant, flavorful…',
#    'url': 'https://www.thekitchn.com/crispy-rice-with-california-avocado-and-tuna-tartare-recipe-23632896',
#    'urlToImage': 'https://cdn.apartmenttherapy.info/image/upload/f_auto,q_auto:eco,c_fill,g_auto,w_1500,ar_3:2/cs%2F2024%2Fk%2Fcalifornia-avocados%2Fcrispy-rice-tuna-tartare%2F2024-ca-avocados-tuna-tartare-3',
#    'publishedAt': '2024-04-02T12:00:00Z',
#    'content': "It's fancy but easy and uses fresh-from-California ingredients.\r\nServes6 to 8\r\nMakes14 to 16\r\nPrep30 minutes\r\nCook25 minutes\r\nWhen you think of what makes California cuisine so special and delicious,… [+6634 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Cheyenne MacDonald',
#    'title': 'Tekken director apparently keeps getting requests to add a Waffle House stage',
#    'description': 'Waffle House is one of those uniquely American institutions-turned-meme. The 24/7 chain is not only a place where you can order a breakfast combo at 3AM, but where unruly customers have been known to show up ready to throw hands (and sometimes chairs). Given …',
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_2000a436-3805-4a61-a90a-faf31de2257e',
#    'urlToImage': None,
#    'publishedAt': '2024-03-31T21:19:13Z',
#    'content': 'Si vous cliquez sur «\xa0Tout accepter\xa0», nos partenaires (y compris 241 qui font partie du Cadre de transparence et de consentement dIAB) et nous utiliserons également des témoins et vos données person… [+982 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'stevenshaw444@gmail.com (Steven Shaw)',
#    'title': 'Three Google Map updates to help you prep for your next vacation',
#    'description': 'Google Maps is introducing three tweaks to help users access relevant information about their destination.',
#    'url': 'https://www.androidcentral.com/apps-software/google-maps-gets-three-new-updates',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/yuBWmaqBPBVsNYRK3uPqHm-1200-80.jpg',
#    'publishedAt': '2024-03-27T16:00:00Z',
#    'content': 'What you need to know\r\n<ul><li>Google has announced three updates to Google Maps that promise to make planning your next trip easier than ever.</li><li>These introduce three major new features – cura… [+3498 chars]'},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Léo Bourdin',
#    'title': 'En cuisine, les ustensiles sont rois\xa0: maryse, pierre de cuisson, tajine algérien, rouleau à empreintes',
#    'description': 'Si, sur la nappe, les couverts se comptent sur les doigts d’une main, derrière les fourneaux, une grande variété d’instruments sert à préparer les aliments. Découvrez leurs origines, parfois oubliées, et la meilleure façon de les utiliser.',
#    'url': 'https://www.lemonde.fr/m-styles/article/2024/03/25/en-cuisine-les-ustensiles-sont-rois-maryse-pierre-de-cuisson-tajine-algerien-rouleau-a-empreintes_6224022_4497319.html',
#    'urlToImage': 'https://img.lemde.fr/2023/11/03/166/0/1227/818/1440/960/60/0/03969d6_308373-3345895.jpg',
#    'publishedAt': '2024-03-25T04:00:10Z',
#    'content': 'LA LISTE DE LA MATINALE\r\nPour préparer des grillades et des tajines, ou encore décorer des pâtes et éviter de gaspiller vos préparations, vos mains seules ny suffiront pas. Ces accessoires viendront … [+3041 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Wales fans nervy ahead of crunch Poland Euro tie',
#    'description': 'Both Wales and Poland fans are gathering in central Cardiff and expect a win for their teams.',
#    'url': 'https://www.bbc.co.uk/news/uk-wales-68668930',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/12CF2/production/_133024077_walesfanswithbuckethats-ltor-curtiswalterlewiswebsterconorthomas.jpg',
#    'publishedAt': '2024-03-26T16:48:57Z',
#    'content': "Nervous football fans have been gathering in Cardiff for Wales' must-win game against Poland as they look to secure Euro 2024 qualification. \r\nBoth sides comfortably won their semi-finals last week -… [+3467 chars]"},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Camille Labro',
#    'title': 'Marie Gerin-Jean\xa0: «\xa0Je sais que la cuisine peut être un acte politique\xa0»',
#    'description': 'A la tête de l’association d’aide alimentaire Ernest, Marie Gerin-Jean orchestre aussi le festival Cheffes\xa0!, qui réunit des cuisinières engagées. La troisième édition se tient les 7\xa0et 8\xa0avril à Marseille et les 19\xa0et 20\xa0mai à Paris.',
#    'url': 'https://www.lemonde.fr/le-monde-passe-a-table/article/2024/04/06/marie-gerin-jean-je-sais-que-la-cuisine-peut-etre-un-acte-politique_6226352_6082232.html',
#    'urlToImage': 'https://img.lemde.fr/2024/03/28/72/0/1200/800/1440/960/60/0/6a513e6_328532-3366316.jpg',
#    'publishedAt': '2024-04-06T11:02:14Z',
#    'content': 'Marie Gerin-Jean, directrice de lassociation Ernest, à Paris, le 14\xa0mars\xa02024. JULIE BALAGUé POUR M LE MAGAZINE DU MONDE\r\n«\xa0Jai passé mon enfance en pleine forêt dans le Var, au cur de la Provence ve… [+2968 chars]'},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Léo Pajon',
#    'title': 'Sang Hoon Degeimbre, chef, et Benoît Blairvacq, jardinier\xa0: «\xa0Si tu ne cultives pas les légumes, tu ne peux pas vraiment les comprendre\xa0»',
#    'description': 'Ces autodictates sont à la tête de L’Air du temps, un deux-étoiles à Liernu, en Belgique. Dans un corps de ferme disposant d’un potager qui assure la quasi-intégralité de leurs besoins, ils proposent une cuisine d’inspiration végétale et coréenne.',
#    'url': 'https://www.lemonde.fr/m-styles/article/2024/04/11/sang-hoon-degeimbre-chef-et-benoit-blairvacq-jardinier-si-tu-ne-cultives-pas-les-legumes-tu-ne-peux-pas-vraiment-les-comprendre_6227245_4497319.html',
#    'urlToImage': 'https://img.lemde.fr/2024/04/09/0/0/4252/2834/1440/960/60/0/f861e0c_1712673208661-img-2966.jpg',
#    'publishedAt': '2024-04-11T14:38:07Z',
#    'content': 'Lun a les cheveux ras, une attitude distante que lon pourrait prendre à tort pour de la froideur, des airs de moine-soldat. Lautre est invariablement hirsute, dune jovialité exubérante et dun enthous… [+2965 chars]'},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Elisa Nguyen Phung',
#    'title': 'Au Halo, à Paris, «\xa0la puissance aromatique du jus de poissons de roche de ce plat de rouget laisse sans voix\xa0»',
#    'description': 'Chaque semaine, un journaliste raconte un produit ou une expérience qui l’a marqué. Comme ce clin d’œil à la bouillabaisse du chef Victor Blanchet, au Halo, à Paris.',
#    'url': 'https://www.lemonde.fr/le-monde-passe-a-table/article/2024/04/01/au-halo-a-paris-la-puissance-aromatique-du-jus-de-poissons-de-roche-de-ce-plat-de-rouget-laisse-sans-voix_6225368_6082232.html',
#    'urlToImage': 'https://img.lemde.fr/2024/03/20/529/0/1125/750/1440/960/60/0/c399496_327591-3363226.jpg',
#    'publishedAt': '2024-04-01T04:00:16Z',
#    'content': 'Le rouget maturé du restaurant Halo, à Paris. ELISA NGUYEN PHUNG POUR M LE MAGAZINE DU MONDE\r\nUne sélection pointue de pièces de créateurs vintage (robes à partir de 300\xa0euros), des flacons de parfum… [+3113 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Harry Kersh',
#    'title': "I visited a McDonald's test kitchen to try its biggest menu overhaul in a decade. The burger patties are a big improvement, but the new Big Mac is too sweet.",
#    'description': "Business Insider's Harry Kersh tried the new recipes for a number of McDonald's burgers, including its famous Big Mac. Here's what he found.",
#    'url': 'https://www.businessinsider.com/mcdonalds-new-burgers-taste-test-of-biggest-changes-in-decade-2024-3',
#    'urlToImage': 'https://i.insider.com/6605434c1caec1275a6a2b49?width=1200&format=jpeg',
#    'publishedAt': '2024-03-30T10:53:01Z',
#    'content': "The new and the old Big Mac burgers.Harry Kersh / Business Insider\r\n<ul><li>McDonald's is rolling out a new burger bun recipe in the US, UK, and Australia.</li><li>It's also changing the way it cooks… [+8736 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "19 ex-McDonald's workers returned to their old restaurant for a 'Class of 1975' reunion almost 50 years after working together",
#    'description': "The former McDonald's workers have stayed close friends over the past 50 years. Some had even met their spouses at the restaurant.",
#    'url': 'https://www.businessinsider.com/former-mcdonalds-workers-reunion-restaurant-missouri-class-of-1975-jobs-2024-4',
#    'urlToImage': 'https://i.insider.com/6616744e16bde8d4ead73f01?width=1200&format=jpeg',
#    'publishedAt': '2024-04-10T11:51:58Z',
#    'content': "Courtesy of McDonald's\r\n<ul><li>A group of former McDonald's workers reunited at their old restaurant 50 years later.</li><li>Some of the former workers traveled in from other states to attend the ce… [+3501 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Dominick Reuter',
#    'title': 'How Chick-fil-A is so successful, selling nearly 5 times as much per restaurant as Taco Bell',
#    'description': "The average stand-alone Chick-fil-A restaurant made a whopping $9.3 million in sales last year, powered by the chain's high-ranking drive-thru operation.",
#    'url': 'https://www.businessinsider.com/how-chick-fil-a-makes-such-high-sales-drive-thru-2024-4',
#    'urlToImage': 'https://i.insider.com/6616df921caec1275a6ea9f8?width=1200&format=jpeg',
#    'publishedAt': '2024-04-11T08:00:01Z',
#    'content': "Chick-fil-A's ultimate weapons are its highly trained staff and an industry-best drive-thru.Chick-fil-A\r\n<ul><li>Chick-fil-A dominated its fast food peers with average restaurant sales of $9.3 millio… [+2857 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': 'A person was taken to hospital after a gallon of ammonia was spilled in a Gordon Ramsay restaurant',
#    'description': "One person\xa0was taken to hospital, Naperville's deputy fire chief said. Staff were able to return to the restaurant later that night.",
#    'url': 'https://www.businessinsider.com/gordon-ramsay-restaurant-ammonia-spill-hospital-naperville-illinois-2024-4',
#    'urlToImage': 'https://i.insider.com/661e575e49058e6693565397?width=1200&format=jpeg',
#    'publishedAt': '2024-04-16T10:39:18Z',
#    'content': 'Stu Forster/Getty Images\r\n<ul><li>A gallon of ammonia was spilled in the basement of a Gordon Ramsay restaurant in Illinois, local emergency services said.</li><li>One person\xa0was taken to hospital in… [+3055 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Lauren Edmonds',
#    'title': "Squatters have taken over Gordon Ramsay's restaurant in London and are threatening legal action",
#    'description': 'Metropolitan Police in London told BI they\'re "aware" of the situation at Gordon Ramsay\'s restaurant and will "take action when appropriate."',
#    'url': 'https://www.businessinsider.com/squatters-gordon-ramsay-restaurant-london-2024-4',
#    'urlToImage': 'https://i.insider.com/661bf7011caec1275a6ff971?width=1200&format=jpeg',
#    'publishedAt': '2024-04-14T17:32:36Z',
#    'content': 'Gordon Ramsay. Icon Sportswire/Getty Images\r\n<ul><li>Squatters are residing in one of Gordon Ramsay\'s restaurants in London.</li><li>The squatters hung a "legal warning" on the restaurant\'s window, a… [+3783 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "A California restaurant owner says he'll 'absolutely' have to put up wages to compete with fast-food chains now paying $20 an hour",
#    'description': '"Why wash dishes for $15 or $17 if I can go get $20 flipping burgers at McDonald\'s," California restaurant owner Sal Vitale said.',
#    'url': 'https://www.businessinsider.com/california-fast-food-20-minimum-wage-restaurant-raise-pay-compete-2024-4',
#    'urlToImage': 'https://i.insider.com/661507693f923f7dab05c3b3?width=1200&format=jpeg',
#    'publishedAt': '2024-04-09T09:43:33Z',
#    'content': 'Michael Siluk/UCG/Universal Images Group via Getty Images\r\n<ul><li>A California restaurant owner says he plans to\xa0raise his wages\xa0after the minimum for fast-food workers shot up to $20.</li><li>Other… [+4519 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Mia Jankowicz',
#    'title': "The squatters in Gordon Ramsay's London restaurant are likely to get kicked out, but the process is a pain, lawyers say",
#    'description': "UK law doesn't criminalize squatting on commercial property, meaning Gordon Ramsay will have to jump through hoops to remove those in his restaurant.",
#    'url': 'https://www.businessinsider.com/gordon-ramsay-faces-headaches-remove-london-squatters-restaurant-heres-why-2024-4',
#    'urlToImage': 'https://i.insider.com/661d3f8a3f923f7dab07e164?width=1200&format=jpeg',
#    'publishedAt': '2024-04-16T15:34:02Z',
#    'content': "Stu Forster/Getty Images, Grace Dean/Business Insider, composite\r\n<ul><li>Gordon Ramsay's hotel-restaurant in London, the York & Albany, was taken over by squatters.</li><li>The occupiers turned it i… [+4838 chars]"},
#   {'source': {'id': None, 'name': 'Theonion.com'},
#    'author': 'The Ellen Show',
#    'title': 'Man Who Came To Restaurant Bald Forced To Wear Maître D’s Toupee',
#    'description': 'NEW YORK—Humiliated by the front-of-house manager’s derision, local diner Geoff Telsey was reportedly forced to wear the maître d’s toupee Friday after arriving at the restaurant Chez Moreau bald. “Sir, we require hair in the dining room,” said the maître d’,…',
#    'url': 'https://www.theonion.com/man-who-came-to-restaurant-bald-forced-to-wear-maitre-d-1851380326',
#    'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/0f8cbbf97afb668ff9b4620634e8d1f8.jpg',
#    'publishedAt': '2024-04-12T12:09:00Z',
#    'content': 'NEW YORKHumiliated by the front-of-house managers derision, local diner Geoff Telsey was reportedly forced to wear the maître ds toupee Friday after arriving at the restaurant Chez Moreau bald. Sir, … [+625 chars]'},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Sabine Maida',
#    'title': 'En cuisine, l’Inox reprend-il du service\xa0?',
#    'description': 'Un temps boudé, ce matériau 100\xa0% recyclable, durable et dénué de substances toxiques fait un retour remarqué dans nos placards. Des poêles aux bouilloires, en passant par les cloches et autres coupelles à glace.',
#    'url': 'https://www.lemonde.fr/m-styles/article/2024/04/01/en-cuisine-l-inox-reprend-il-du-service_6225444_4497319.html',
#    'urlToImage': 'https://img.lemde.fr/2024/02/21/281/0/1500/1000/1440/960/60/0/32dbc50_323721-3360331.jpg',
#    'publishedAt': '2024-04-01T14:00:06Z',
#    'content': 'LOVEÉCRU\r\nComme son nom lindique, lacier inoxydable résiste à tout \xa0rayons UV, rayures, chocs, humidité\xa0, même aux caprices des tendances. Boudé depuis une bonne dizaine dannées au profit de la céram… [+1783 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Jennifer Ouellette',
#    'title': 'Tastes like chicken? Think again—edible ants have distinctive flavor profiles.',
#    'description': 'Go ahead, eat some ants. We triple dog dare you.',
#    'url': 'https://arstechnica.com/science/2024/03/tastes-like-chicken-think-again-edible-ants-have-distinctive-flavor-profiles/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2024/03/edible2-760x380.jpg',
#    'publishedAt': '2024-03-19T14:29:54Z',
#    'content': 'Enlarge/ Chicatana ants have a nutty, fatty flavor. They are consumed in parts of Mexico to add texture and flavor to dishes.\r\n54\r\nEdible insects, like ants, are considered a delicacy in many culture… [+3136 chars]'},
#   {'source': {'id': None, 'name': 'Dezeen'},
#    'author': 'Jon Astbury',
#    'title': 'Hetedik Műterem and Studio Konstella extend old ski lodge in Budapest',
#    'description': 'Hungarian practices Hetedik Műterem and Studio Konstella have revamped and extended the Normafa Ski Lodge restaurant in Budapest with the shingle-clad pavilion, which aims to evoke "the purity of a mountain hut". Located in Normafa Park to the west of the Hun…',
#    'url': 'https://www.dezeen.com/2024/03/27/normafa-ski-lodge-hetedik-muterem-studio-konstella/',
#    'urlToImage': 'https://static.dezeen.com/uploads/2024/02/hero-forest-pavilion-normafa-ski-lodge-hetedik-muterem-studio-konstella-budapest_dezeen_2364_col_6-600x600.jpg',
#    'publishedAt': '2024-03-27T11:30:56Z',
#    'content': 'Hungarian practices Hetedik Műterem and Studio Konstella have revamped and extended the Normafa Ski Lodge restaurant in Budapest with the shingle-clad pavilion, which aims to evoke "the purity of a m… [+2560 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Ana Altchek,Taylor Rains',
#    'title': 'Singapore is adding luxury upgrades to its premium economy cabin as it strives to maintain its world-best title',
#    'description': 'Premium passengers on Singapore Airlines can browse through over 200 new food and drink options and drift off in comfort with an amenity kit.',
#    'url': 'https://www.businessinsider.com/singapore-airlines-premium-economy-cabin-changes-meals-drinks-menu-2024-3',
#    'urlToImage': 'https://i.insider.com/65f879ed3037f8e817515ccb?width=1200&format=jpeg',
#    'publishedAt': '2024-03-19T15:28:24Z',
#    'content': 'Singapore Airlines is adding over 200 menu items for premium passengers starting March 31.NurPhoto/Getty\r\n<ul><li>Singapore Airlines is offering a luxurious new in-flight experience for its premium e… [+5883 chars]'},
#   {'source': {'id': None, 'name': 'Design-milk.com'},
#    'author': 'Joseph Sgambati III',
#    'title': 'The kodo hotel Is an Architectural Touchstone for Wellness',
#    'description': 'The kodo hotel is a minimalist architectural touchstone borne from the synergy between collaborators M_Royce Architecture and creative studio Gry Space nuanced in wabi-sabi.',
#    'url': 'https://design-milk.com/the-kodo-hotel-is-an-architectural-touchstone-for-wellness/',
#    'urlToImage': 'https://design-milk.com/images/2024/04/Kodo-Hotel-Gry-Space-MRoyce-Architecture-00-hero.jpg',
#    'publishedAt': '2024-04-04T17:00:15Z',
#    'content': 'Calcium, iron, sulfur, and magnesium. These minerals are just a small sample from the shared elemental composition that links humans to the earth, and yet the hubris of man has led many builders astr… [+4477 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Matthew Ponsford',
#    'title': 'Citizen Zoo Is Rewilding the UK, One Grasshopper at a Time',
#    'description': 'The London-based social enterprise is turning regular people into at-home zookeepers.',
#    'url': 'https://www.wired.com/story/citizen-zoo-rewilding-uk/',
#    'urlToImage': 'https://media.wired.com/photos/61b3bb188fad380cdeaf62e4/191:100/w_1280,c_limit/0922-WIRED-09.jpg',
#    'publishedAt': '2024-03-20T03:42:51Z',
#    'content': 'The large marsh grasshopper was once ever-present across Eastern Englands wetlands. But after decades of habitat destruction, these handsome insects are now fragmented and locally extinct, holding ou… [+3706 chars]'},
#   {'source': {'id': None, 'name': 'The New Yorker'},
#    'author': 'Shauna Lyon',
#    'title': 'Exquisite Beach Vibes at Quique Crudo',
#    'description': 'Shauna Lyon on Quique Crudo, a seafood-focussed counter from the owners of Casa Enrique—the first Mexican restaurant in the city to earn a Michelin star—that has opened in the West Village.',
#    'url': 'https://www.newyorker.com/magazine/2024/04/01/exquisite-beach-vibes-at-quique-crudo',
#    'urlToImage': 'https://media.newyorker.com/photos/65fb1298088bfbe25f5e4669/16:9/w_1280,c_limit/r43987.jpg',
#    'publishedAt': '2024-03-22T10:00:00Z',
#    'content': 'Is it spring break yet? If youre in the mood for beachand by the last week of March who isntyou might head to Quique Crudo, a tiny walk-in-only restaurant in the West Village, where the chef Cosme Ag… [+3027 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': None,
#    'title': 'Visa, Mastercard settle long-running antitrust suit over swipe fees with merchants',
#    'description': 'Visa and Mastercard announced a major settlement with U.S. merchants, potentially ending years of litigation over the fees charged every time a credit or debit card is used in a store or restaurant.',
#    'url': 'https://www.npr.org/2024/03/27/1241112660/visa-mastercard-settle-long-running-antitrust-suit-over-swipe-fees-with-merchant',
#    'urlToImage': 'https://media.npr.org/assets/img/2024/03/27/ap24086476174843_wide-e8d184340da1e6c1daf786109f4418c4aaeac7a7-s1400-c100.jpg',
#    'publishedAt': '2024-03-27T06:08:25Z',
#    'content': 'Visa and MasterCard announced, Tuesday, March 26, 2024, a settlement with U.S. merchants related to swipe fees, a development that could potentially save consumers tens of billions of dollars.\r\nMark … [+4798 chars]'},
#   {'source': {'id': None, 'name': 'BleepingComputer'},
#    'author': 'Lawrence Abrams',
#    'title': 'OpenTable is adding your first name to previously anonymous reviews',
#    'description': "Restaurant reservation platform OpenTable says that all reviews on the platform will no longer be fully anonymous starting May 22nd and will now show members' profile pictures and first names.",
#    'url': 'https://www.bleepingcomputer.com/news/technology/opentable-is-adding-your-first-name-to-previously-anonymous-reviews/',
#    'urlToImage': 'https://www.bleepstatic.com/content/hl-images/2024/04/11/opentable.jpg',
#    'publishedAt': '2024-04-11T22:24:40Z',
#    'content': "Restaurant reservation platform OpenTable says that all reviews on the platform will no longer be fully anonymous starting May 22nd and will now show members' profile pictures and first names.\r\nOpenT… [+2185 chars]"},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Léo Pajon',
#    'title': 'Guide Michelin 2024\xa0: le Breton Ronan Kervarrec obtient une deuxième étoile pour Le Saison',
#    'description': 'Dans son établissement près de Rennes, le chef convoque le souvenir de son père aubergiste tout en laissant éclater son inspiration iodée\xa0à coups d’algues, de coques et de sauces ébouriffantes.',
#    'url': 'https://www.lemonde.fr/m-styles/article/2024/03/18/guide-michelin-2024-le-breton-ronan-kervarrec-obtient-une-deuxieme-etoile-pour-le-saison_6222739_4497319.html',
#    'urlToImage': 'https://img.lemde.fr/2024/03/18/0/17/4099/2733/1440/960/60/0/7c75f3d_1710768271427-02-jmg-hl-r-kervarrec-17-copie.jpg',
#    'publishedAt': '2024-03-18T17:57:31Z',
#    'content': 'Ronan Kervarrec, dans son restaurant Le Saison, à Saint-Grégoire (Ille-et-Vilaine), le 15 mars 2024. JEAN-MATTHIEU GAUTIER / HANS LUCAS POUR «\xa0LE MONDE\xa0»\r\nPeu de chefs chevronnés avouent que cuisiner… [+2932 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': 'Here are 5 ways fast-food restaurants in California are cutting costs to cover the new minimum wage',
#    'description': "California fast-food franchisees say they're desperate to find ways to remain profitable and offset the state's new $20 minimum wage.",
#    'url': 'https://www.businessinsider.com/fast-food-california-layoffs-less-staff-to-cover-wage-hike-2024-4',
#    'urlToImage': 'https://i.insider.com/660bf9871caec1275a6bafcf?width=1200&format=jpeg',
#    'publishedAt': '2024-04-03T10:47:44Z',
#    'content': "McDonald's. Allen J. Schaben/Los Angeles Times via Getty Images\r\n<ul><li>California fast-food franchisees say they're desperate to find ways to remain profitable.\xa0</li><li>Restaurants are trying to o… [+4681 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "A California franchisee says he's reducing staffing, raising prices, and mulling kiosks to cover the $20 wage. Closing stores is a last resort.",
#    'description': "A Vitality Bowls franchisee in San Jose told BI how he's trying to absorb California's $20 minimum wage for fast-food workers.",
#    'url': 'https://www.businessinsider.com/california-restaurant-operator-adapts-to-20-wage-kiosks-less-staff-2024-4',
#    'urlToImage': 'https://i.insider.com/661d10071caec1275a7006c1?width=1200&format=jpeg',
#    'publishedAt': '2024-04-17T09:09:43Z',
#    'content': "A Vitality Bowls franchisee in San Jose told BI how he's trying to absorb California's $20 minimum wage for fast-food workers.Alexander Spatari/Getty Images\r\n<ul><li>A franchisee told BI how he's try… [+4310 chars]"},
#   {'source': {'id': None, 'name': '101cookbooks.com'},
#    'author': 'Heidi Swanson',
#    'title': 'Easter Brunch Ideas',
#    'description': 'A collection of all-star Easter brunch ideas ranging from a favorite breakfast casserole recipe to the best waffle recipe I know. All worth making year-round as well!\nContinue reading Easter Brunch Ideas on 101 Cookbooks',
#    'url': 'https://www.101cookbooks.com/easter-brunch-ideas/',
#    'urlToImage': 'https://images.101cookbooks.com/EASTER-BRUNCH-RECIPES-h.jpg?w=680',
#    'publishedAt': '2024-03-22T21:45:11Z',
#    'content': "I know many of you are on the hunt for good Easter brunch recipes right now. Here are a few favorites. I'm highlighting them here for Easter, but they're all a part of my year-round repertoire. For b… [+8307 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Brittany Chang',
#    'title': "I sailed on the world's 2 largest cruise ships. The older one was just as good — and $1,000 cheaper.",
#    'description': "Royal Caribbean's Icon of the Seas launched in January, dethroning its Wonder of the Seas predecessor as the world's largest cruise ship.",
#    'url': 'https://www.businessinsider.com/royal-caribbean-largest-cruise-ships-wonder-icon-compared-2024-4',
#    'urlToImage': 'https://i.insider.com/660c4dc53f923f7dab03ca78?width=1200&format=jpeg',
#    'publishedAt': '2024-04-03T09:00:02Z',
#    'content': "Royal Caribbean' operates the two world's largest cruise ships, Wonder of the Seas and Icon of the Seas. Here's how the two compare.Pieter De Boer\r\n<ul><li>Royal Caribbean operates many of the cruise… [+10155 chars]"},
#   {'source': {'id': 'die-zeit', 'name': 'Die Zeit'},
#    'author': 'ZEIT ONLINE: wochenmarkt - Moritz Hackl',
#    'title': 'Fine Dining in München: Herr Kunz greift nach den Sternen',
#    'description': "Während anderswo Spitzenrestaurants schließen, hat Chefkoch Christoph Kunz in München das Komu eröffnet. Sein Ziel: zwei Michelin-Sterne im ersten Jahr. Klappt's?",
#    'url': 'https://www.zeit.de/zeit-magazin/wochenmarkt/2024-03/fine-dining-muenchen-restaurant-christoph-kunz-wochenmarkt',
#    'urlToImage': 'https://img.zeit.de/zeit-magazin/wochenmarkt/2024-03/michelin-stern-christoph-kunz-komu-teaser/wide__1300x731',
#    'publishedAt': '2024-03-26T14:17:37Z',
#    'content': 'In ganz Deutschland müssen Wirte ihre Groschen beisammenhalten, ihre Karten neu berechnen und schauen, wie sie trotz Inflation, angehobener Mehrwertsteuer und konsumzögerlich gewordener Gäste halbweg… [+469 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': 'A man who has been going to Bojangles every week after church for decades just had a surprise 105th birthday party there',
#    'description': 'The 105-year-old man usually goes to Bojangles after church every week for its Leg & Thigh meal with a group of family members and friends.',
#    'url': 'https://www.businessinsider.com/bojangles-customer-visits-every-week-celebrates-105th-birthday-at-restaurant-2024-3',
#    'urlToImage': 'https://i.insider.com/66040ef91caec1275a69cde2?width=1200&format=jpeg',
#    'publishedAt': '2024-03-28T10:05:49Z',
#    'content': 'Charlie Lentz (right) pictured at his 105th birthday celebrations at a Bojangles restaurant in Winston-Salem, North Carolina, with Bojangles regional manager Horace Spencer (left).Courtesy of Bojangl… [+1978 chars]'},
#   {'source': {'id': None, 'name': 'Dezeen'},
#    'author': 'Alice Laycock',
#    'title': 'Panigiri dining system by Extremis among seven new products on Dezeen Showroom',
#    'description': 'Dezeen Showroom: a modular outdoor dining table system\xa0that combines various types of seating is among seven new products featured on Dezeen Showroom. Panigiri dining system by Extremis Belgian furniture brand\xa0Extremis has released a modular dining system tha…',
#    'url': 'https://www.dezeen.com/2024/03/18/panigiri-dining-system-extremis-furniture-seating-tiles-dezeen-showroom/',
#    'urlToImage': 'https://static.dezeen.com/uploads/2024/03/extremis-panigiri-dezeen-showroom_dezeen_2364_col_0-600x600.jpg',
#    'publishedAt': '2024-03-18T08:00:39Z',
#    'content': 'Dezeen Showroom: a modular outdoor dining table system\xa0that combines various types of seating is among seven new products featured on Dezeen Showroom.\r\nPanigiri dining system by Extremis\r\nBelgian fur… [+2990 chars]'},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Le Goût du Monde',
#    'title': 'Avoir du bol\xa0! Trois recettes de nouilles instantanées (ou presque)',
#    'description': 'Mardi, c’est veggie\xa0! Cette semaine, on cuisine ces noodles chinoises véganes nourrissantes et légères… d’un coup de baguette magique.',
#    'url': 'https://www.lemonde.fr/le-monde-passe-a-table/article/2024/04/09/avoir-du-bol-trois-recettes-de-nouilles-instantanees-ou-presque_6226766_6082232.html',
#    'urlToImage': 'https://img.lemde.fr/2024/04/02/1249/0/3000/2000/1440/960/60/0/e0f290c_1712073806779-08122023-cheynese-book-bd-8.jpg',
#    'publishedAt': '2024-04-09T03:30:13Z',
#    'content': 'Dans le tour du monde en 80 recettes véganes dAsie et dOrient que propose linfluenceuse «\xa0food\xa0» Cheynese Khachame dans son livre Ma cuisine végétale à partager (Solar) préfacé par la restauratrice «… [+2795 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Grace Dean',
#    'title': "McSki in Sweden is McDonald's only ski-thru restaurant, where you can grab a Big Mac to take down the slopes",
#    'description': "McDonald's has just one McSki, or Ski-Thru, located in one of Sweden's biggest ski resorts. You can get table service, or just ski off with your food.",
#    'url': 'https://www.businessinsider.com/mcski-sweden-ski-thru-mcdonalds-photos-2024-3',
#    'urlToImage': 'https://i.insider.com/65f9b750895d822030323f16?width=1200&format=jpeg',
#    'publishedAt': '2024-03-31T09:15:01Z',
#    'content': "McDonald's Ski-Thru restaurant in Sweden.McDonald's Sverige\r\n<ul><li>McDonald's has just one McSki, or Ski-Thru, located in one of Sweden's biggest resorts.</li><li>Hunger skiers can stop for hot cho… [+4011 chars]"},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Benj Edwards',
#    'title': 'AI hype invades Taco Bell and Pizza Hut',
#    'description': 'Everything is suddenly "AI" in corporate food marketing, and we may have hit peak buzz.',
#    'url': 'https://arstechnica.com/information-technology/2024/04/ai-hype-invades-taco-bell-and-pizza-hut/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2024/04/pizza_hut_sign-760x380.jpg',
#    'publishedAt': '2024-04-03T18:59:56Z',
#    'content': '47\r\nDepending on who you ask about AI (and how you define it), the technology may or may not be useful, but one thing is for certain: AI hype is dominating corporate marketing these dayseven in fast … [+3296 chars]'},
#   {'source': {'id': None, 'name': 'The Points Guy'},
#    'author': 'Donna Heiderstadt',
#    'title': 'Norwegian Cruise Line food: The ultimate cruise guide to restaurants and dining on board',
#    'description': 'Norwegian Cruise Line has always been a bit of a rebel when it comes to food. Back in 2000, the company introduced the concept of Freestyle Cruising, and with it, the idea of Freestyle Dining. Guests no longer were assigned to traditional early or late dinner…',
#    'url': 'https://thepointsguy.com/guide/norwegian-cruise-line-food-restaurants/',
#    'urlToImage': 'https://thepointsguy.global.ssl.fastly.net/us/originals/2023/11/NCL_Ice_Cream_2030-v3-final-scaled.jpeg',
#    'publishedAt': '2024-03-21T12:30:07Z',
#    'content': 'Norwegian Cruise Line has always been a bit of a rebel when it comes to food.\r\nBack in 2000, the company introduced the concept of Freestyle Cruising, and with it, the idea of Freestyle Dining. Guest… [+24479 chars]'},
#   {'source': {'id': None, 'name': 'Design-milk.com'},
#    'author': 'Joseph Sgambati III',
#    'title': 'DMTV Milkshake: James De Wulf on Concrete and Self-Discovery',
#    'description': "In this DMTV Milkshake, James De Wulf shares how he pioneered his concrete couture practice with proprietary designs, and how it hasn't always been easy.",
#    'url': 'https://design-milk.com/dmtv-milkshake-james-de-wulf-on-concrete-and-self-discovery/',
#    'urlToImage': 'https://design-milk.com/images/2024/04/James-de-Wulf-00-Lotus-Dining-table.jpg',
#    'publishedAt': '2024-04-10T16:00:26Z',
#    'content': 'It hasnt always been glamorous, bronze-gilded concrete sculptures for artisan James De Wulf, as he modestly shares of his decorated résumé in this week’s Milkshake. Id say it was failure, failing at … [+3348 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Jenny Powers',
#    'title': "I make up to $2,700 in tips a week as a server. Dropping out of college was the best thing I could've done.",
#    'description': 'Kyle Zajac works as a server at a high-end steakhouse in Indianapolis. He makes thousands in tips, earns PTO, and is eligible for health insurance.',
#    'url': 'https://www.businessinsider.com/waiter-dropped-out-college-makes-thousands-tips-weekly-2024-4',
#    'urlToImage': 'https://i.insider.com/660c566316bde8d4ead4d98a?width=1200&format=jpeg',
#    'publishedAt': '2024-04-03T09:06:01Z',
#    'content': 'Kyle Zajac is a waiter at a high-end steakhouse in Indianapolis.Courtesy of Kyle Zajac\r\n<ul><li>Kyle Zajac, a 22-year-old server, earns thousands of tips weekly at an upscale steakhouse.</li><li>Zaja… [+5503 chars]'},
#   {'source': {'id': None, 'name': 'Food52.com'},
#    'author': 'Nicole Davis',
#    'title': 'Chef Jackie Carnesi Brings Her South Texas Spirit to an Iconic Brooklyn Diner',
# ...
#    'content': 'Nonstop access to food is one of the main draws of cruising, and Holland America Line offers a variety of venues and menus for every craving, no matter the time of day.\r\nEvery Holland America ship of… [+9375 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Lawrence Bonk',
#    'title': 'DoorDash is testing a drone delivery feature in Virginia',
#    'description': 'DoorDash just announced the launch\r\n of a drone delivery pilot program, in partnership with Alphabet’s Wing\r\n. The testing began in Christiansburg, VA (approximate population 22,000), and is limited to only "eligible items" from fast food chain Wendy\'s. Wheth…',
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_d7c292ae-82a3-49ad-b8a2-19bf866f5f34',
#    'urlToImage': None,
#    'publishedAt': '2024-03-21T16:30:15Z',
#    'content': 'Si vous cliquez sur «\xa0Tout accepter\xa0», nos partenaires (y compris 241 qui font partie du Cadre de transparence et de consentement dIAB) et nous utiliserons également des témoins et vos données person… [+982 chars]'},
#   {'source': {'id': None, 'name': 'Cheezburger.com'},
#    'author': 'BenWeiss, BenWeiss',
#    'title': "'The restaurant thought I had dined and dashed': Customer takes too long in the bathroom, server calls the cops thinking he dined and dashed",
#    'description': 'Talk about a humiliating dining experience! This patron had an unfortunate emergency that required a relatively long trip to the bathroom. The trip took so long, in fact, that his server began to think he dined and dashed because he took his things with him. …',
#    'url': 'https://cheezburger.com/25176581/the-restaurant-thought-i-had-dined-and-dashed-customer-takes-too-long-in-the-bathroom-server-calls',
#    'urlToImage': 'https://i.chzbgr.com/thumb1200/25176581/h9E5ED1E9/dashed-customer-takes-too-long-in-the-bathroom-server-calls-the-cops-thinking-he-dined-and-dashed',
#    'publishedAt': '2024-03-28T18:00:00Z',
#    'content': 'Talk about a humiliating dining experience! This patron had an unfortunate emergency that required a relatively long trip to the bathroom. The trip took so long, in fact, that his server began to thi… [+1089 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Douglas Yu, Senior Contributor, \n Douglas Yu, Senior Contributor\n https://www.forbes.com/sites/douglasyu/',
#    'title': 'CAVU Backed Gymkhana Fine Foods Raises $3 Million To Bring High-End Indian Recipes To Grocery',
#    'description': 'Gymkhana has emerged to become a fine dining landmark after opening its first restaurant in London 10 years ago, and now its high-end Indian recipes are coming to retail.',
#    'url': 'https://www.forbes.com/sites/douglasyu/2024/04/08/cavu-backed-gymkhana-fine-foods-raises-3-million-to-bring-high-end-indian-recipes-to-grocery/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6612d7beb3f0817e30dcf5f9/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2024-04-08T15:00:00Z',
#    'content': 'Cofounders of JKS Restaurants, Karam (left) and Jyotin Sethi (middle), partners with former Mars ... [+] executive Gulrez Arora (right) to launch CPG brand Gymkhana Fine Foods.\r\nGymkhana Fine Foods\r\n… [+5694 chars]'},
#   {'source': {'id': None, 'name': 'A Beautiful Mess'},
#    'author': 'Elsie Larson',
#    'title': 'Arnold Palmer Drink',
#    'description': 'The Arnold Palmer is a refreshing summer drink from the 1960s. It is made by combining lemonade and iced tea. In my opinion, this winning combination is better than iced tea or lemonade. They pair so well together. Although this recipe is extremely simple, th…',
#    'url': 'https://abeautifulmess.com/arnold-palmer-drink/',
#    'urlToImage': 'https://abeautifulmess.com/wp-content/uploads/2024/03/Arnold-Palmer-recipe.jpg',
#    'publishedAt': '2024-04-02T13:03:00Z',
#    'content': 'The Arnold Palmer is a refreshing summer drink from the 1960s. It is made by combining lemonade and iced tea. In my opinion, this winning combination is better than iced tea or lemonade. They pair so… [+6322 chars]'},
#   {'source': {'id': 'focus', 'name': 'Focus'},
#    'author': 'Von FOCUS-online-Autorin Annika van der Hoek',
#    'title': 'Fine Dining in Franken - Alexander Herrmann: Diese Restaurants besitzt er',
#    'description': 'Alexander Herrmann ist als Koch und Gastronom einem breiten Fernsehpublikum bekannt. Inzwischen kann Herrmann drei Restaurants und ein Bistro mit unterschiedlichen kulinarischen Ausrichtungen sein eigen nennen.Von FOCUS-online-Autorin Annika van der Hoek',
#    'url': 'https://www.focus.de/panorama/fine-dining-in-franken-alexander-herrmann-diese-restaurants-besitzt-er_id_259836458.html',
#    'urlToImage': 'https://p6.focus.de/img/panorama/id_259836457/alexander-herrmann.jpg?im=Crop%3D%280%2C118%2C3771%2C1885%29%3BResize%3D%281200%2C627%29&impolicy=perceptual&quality=mediumHigh&hash=74eb73de29771352bfdeadc299d77b546651db64051436a0048d1cc7780fc3a0',
#    'publishedAt': '2024-04-14T18:30:00Z',
#    'content': 'Alexander Herrmann ist als Koch und Gastronom einem breiten Fernsehpublikum bekannt. Inzwischen kann Herrmann drei Restaurants und ein Bistro mit unterschiedlichen kulinarischen Ausrichtungen sein ei… [+3905 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Dan DeFrancesco',
#    'title': "One of Wall Street's most powerful people is predicting that a 4-day workweek is coming",
#    'description': 'Steve Cohen put his money where his mouth is regarding the four-day workweek.',
#    'url': 'https://www.businessinsider.com/four-day-workweek-wall-street-steve-cohen-aii-rise-pga-2024-3',
#    'urlToImage': 'https://i.insider.com/660e8bc416bde8d4ead589dc?width=1200&format=jpeg',
#    'publishedAt': '2024-04-04T12:37:39Z',
#    'content': 'More employers are exploring concepts like a four-day workweek but what many people want is flexibility.onetime/Getty Images\r\n<ul><li>This post originally appeared in the Insider Today newsletter.</l… [+7527 chars]'},
#   {'source': {'id': None, 'name': 'Cool Hunting'},
#    'author': 'David Graver',
#    'title': 'Watches & Wonders 2024: Jaeger-LeCoultre’s Precision Atelier with Chef Himanshu Saini',
#    'description': "A gastronomic quartet from the two-Michelin-starred culinary mastermind, imagined with ingredients from Switzerland's Vallée de Joux The most prestigious global gathering for individuals interested in wristwatches and other time-telling devices, Watches & …",
#    'url': 'http://coolhunting.com/design/watches-wonders-2024-jaeger-lecoultres-precision-atelier-with-chef-himanshu-saini/',
#    'urlToImage': 'https://150102931.v2.pressablecdn.com/wp-content/uploads/2024/04/JLC_MADE_OF_MAKERS__HS__07592__sRGB__8Bits__FULL-scaled.jpg',
#    'publishedAt': '2024-04-08T21:47:13Z',
#    'content': "A gastronomic quartet from the two-Michelin-starred culinary mastermind, imagined with ingredients from Switzerland's Vallée de Joux\n\n\nRead\nDesign\r\n\n\n\n\n\nWatches & Wonders 2024: Jaeger-LeCoultre’s Pre… [+4661 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Imad Khan',
#    'title': 'Perplexity AI Review: Imagine ChatGPT with an Internet Connection - CNET',
#    'description': "Perplexity AI's bones are built on GPT-3.5, but it has a connection to the open internet for up-to-date information.",
#    'url': 'https://www.cnet.com/tech/services-and-software/perplexity-ai-review-imagine-chatgpt-with-an-internet-connection/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/80e97382e989ea5ff8dae8a21883623135407efe/hub/2024/03/27/9449480e-5bec-48f6-ab5c-efbe62a9d1c0/perplexity-ai-7622.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2024-04-02T15:00:00Z',
#    'content': 'Basic info:\r\n<ul><li>Price: Free</li><li>Availability: Web or mobile app</li><li>Features: Voice recognition, Reddit dataset</li><li>Image generation: No, paid version only</li></ul>Imagine if ChatGP… [+12412 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Kaitlyn McInnis, Contributor, \n Kaitlyn McInnis, Contributor\n https://www.forbes.com/sites/kaitlynmcinnis/',
#    'title': '6 Of The Best Vegetarian And Vegan-Friendly Restaurants In Halifax, Nova Scotia',
#    'description': 'Halifax is known for its seafood more so than its plant-based cuisine—but that doesn’t mean finding vegetarian and vegan-friendly restaurants will be difficult.',
#    'url': 'https://www.forbes.com/sites/kaitlynmcinnis/2024/03/26/6-of-the-best-vegetarian-and-vegan-friendly-restaurants-in-halifax-nova-scotia/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6603137615996cb546ed074f/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2024-03-26T18:28:01Z',
#    'content': 'Halifax, Nova Scotia, Canada: People eating on the Halifax Waterfront\r\ngetty\r\nHalifax is known for its seafood more so than its plant-based cuisinebut that doesnt mean finding vegetarian and vegan-fr… [+3049 chars]'},
#   {'source': {'id': None, 'name': 'Journal du geek'},
#    'author': 'Amandine Jonniaux',
#    'title': 'PFAS\xa0: cuisine, cosmétiques… comment les repérer chez vous\xa0?',
#    'description': 'Les polluants éternels sont partout, mais comment limiter leur présence dans votre environnement ?',
#    'url': 'https://www.journaldugeek.com/2024/04/08/pfas-cuisine-cosmetiques-comment-les-reperer-chez-vous/',
#    'urlToImage': 'https://www.journaldugeek.com/app/uploads/2024/04/steak-poele-antiadhesive.jpeg',
#    'publishedAt': '2024-04-08T12:27:33Z',
#    'content': 'Ce jeudi 4 avril, les députés examinaient la proposition de loi anti PFAS (prononcez “piface”), visant à “protéger la population des risques liés aux polluants éternels” omniprésents dans le quotidie… [+2528 chars]'},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Camille Labro',
#    'title': 'Luana Belmondo, cheffe et autrice\xa0: «\xa0La cuisine tenait une place centrale chez nous, comme dans la plupart des familles italiennes\xa0»',
#    'description': 'L’autrice et cuisinière médiatique Luana Belmondo sort un livre et un documentaire sur son périple culinaire à travers l’Italie avec son fils aîné. Elle partage une des recettes de son enfance, les saltimboccas.',
#    'url': 'https://www.lemonde.fr/m-styles/article/2024/04/12/luana-belmondo-cheffe-et-autrice-la-cuisine-tenait-une-place-centrale-chez-nous-comme-dans-la-plupart-des-familles-italiennes_6227392_4497319.html',
#    'urlToImage': 'https://img.lemde.fr/2024/04/03/124/0/1200/800/1440/960/60/0/e0084dd_329525-3367286.jpg',
#    'publishedAt': '2024-04-12T09:30:10Z',
#    'content': 'La cheffe, animatrice et autrice culinaire Luana Belmondo, le 21\xa0mars 2024, à Paris. JULIE BALAGUé POUR M LE MAGAZINE DU MONDE\r\nJe suis née dans une casserole. Toute mon enfance, le matin, jai été ré… [+3179 chars]'},
#   {'source': {'id': None, 'name': 'The Points Guy'},
#    'author': 'Lyssa Goldberg',
#    'title': 'Carnival cruise food: The ultimate guide to restaurants and dining on board',
#    'description': 'On a Carnival cruise, food is always one of the highlights. From Guy Fieri burgers to fancy steaks at Fahrenheit 555, you’ll find endless options to satisfy your hunger in a highly enjoyable fashion. In fact, there’s often more to eat and explore than you cou…',
#    'url': 'https://thepointsguy.com/guide/carnival-cruise-food/',
#    'urlToImage': 'https://thepointsguy.global.ssl.fastly.net/us/originals/2024/03/carnival-bonsai-sushi.jpg',
#    'publishedAt': '2024-03-22T16:00:59Z',
#    'content': "On a Carnival cruise, food is always one of the highlights. From Guy Fieri burgers to fancy steaks at Fahrenheit 555, you'll find endless options to satisfy your hunger in a highly enjoyable fashion.… [+18594 chars]"},
#   {'source': {'id': None, 'name': 'Dezeen'},
#    'author': 'Alice Laycock',
#    'title': 'Seven outdoor furnishings to welcome the beginning of spring',
#    'description': "Dezeen Showroom: as we emerge from the dark winter months, we've brought together a range of outdoor furnishings published on Dezeen Showroom including garden seating, dining sets and sun loungers. The following roundup features an outdoor chair made from han…",
#    'url': 'https://www.dezeen.com/2024/03/29/outdoor-furniture-seating-products-furnishings-dezeen-showroom/',
#    'urlToImage': 'https://static.dezeen.com/uploads/2024/03/panigiri-dining-system-extremis-design_dezeen_2364_hero-600x600.jpg',
#    'publishedAt': '2024-03-29T17:00:24Z',
#    'content': "Dezeen Showroom: as we emerge from the dark winter months, we've brought together a range of outdoor furnishings published on Dezeen Showroom including garden seating, dining sets and sun loungers.\r\n… [+3318 chars]"},
#   {'source': {'id': None, 'name': 'A Beautiful Mess'},
#    'author': 'Elsie Larson',
#    'title': 'Cherry Bomb Shot',
#    'description': 'The Cherry Bomb Shot is a fun party shot recipe made using cherry flavored vodka (or liqueur), energy drink and grenadine. If you’re looking for a fun, flavorful cocktail, we’re excited for you to try this Cherry Bomb recipe. With prep only taking a couple of…',
#    'url': 'https://abeautifulmess.com/cherry-bomb-shot/',
#    'urlToImage': 'https://abeautifulmess.com/wp-content/uploads/2024/02/Cherry-Bomb-Shot.jpg',
#    'publishedAt': '2024-04-06T13:03:00Z',
#    'content': 'The Cherry Bomb Shot is a fun party shot recipe made using cherry flavored vodka (or liqueur), energy drink and grenadine. If you’re looking for a fun, flavorful cocktail, we’re excited for you to tr… [+4421 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Scott Gilbertson',
#    'title': 'The Best Instax Cameras and Printers (2024): Film Types, Tips, and More',
#    'description': 'Should you buy an Instax Mini? Instax Mini Evo? Instax Square? We demystify Fujifilm’s Instax lineup to help you find the perfect instant camera (or printer).',
#    'url': 'https://www.wired.com/story/best-instax-cameras-and-printers/',
#    'urlToImage': 'https://media.wired.com/photos/65f8a17ffbc705f16bd6f3d4/191:100/w_1280,c_limit/instax-camera-guide-collage-SOURCE-Scott-Gilbertson.jpg',
#    'publishedAt': '2024-03-19T12:00:00Z',
#    'content': 'Fujifilm introduced a new app with the Mini 12 called Instax Up (Android, iOS). The key function is that it will "scan" (photograph) your Instax prints, allowing you to store and share them online. I… [+5837 chars]'},
#   {'source': {'id': None, 'name': 'Mental Floss'},
#    'author': 'Jake Rossen',
#    'title': 'This Fine Dining Experience in Space Will Cost $495,000 a Plate',
#    'description': 'SpaceVIP plans to send six gastronomic guests 100,000 feet above sea level in a giant hydrogen balloon.',
#    'url': 'https://www.mentalfloss.com/posts/spaceship-neptune-space-food',
#    'urlToImage': 'https://images2.minutemediacdn.com/image/upload/c_crop,w_2121,h_1193,x_0,y_0/c_fill,w_1440,ar_16:9,f_auto,q_auto,g_auto/images/voltaxMediaLibrary/mmsport/mentalfloss/01hs96nfr75283rdkcg2.jpg',
#    'publishedAt': '2024-03-18T18:51:00Z',
#    'content': 'In the early days of space exploration, astronauts consumed tubes of applesauce and puréed beef. Appetizing? Not really. But as time and privatized space exploration goes on, space food is advancing:… [+2941 chars]'},
#   {'source': {'id': None, 'name': 'FOX40'},
#    'author': 'Veronica Catlin',
#    'title': 'Sacramento Cracker Barrel suddenly closes for good',
#    'description': '(FOX40.COM) — The only Cracker Barrel in Sacramento recently closed its doors for good. A post on Reddit shows what appear to be construction workers...',
#    'url': 'https://fox40.com/news/local-news/sacramento/sacramento-cracker-barrel-closes/',
#    'urlToImage': 'https://media.zenfs.com/en/ktxl_articles_604/f628719c8853362ff728b9f0c4fc0ff6',
#    'publishedAt': '2024-04-16T23:35:01Z',
#    'content': '(FOX40.COM) The only Cracker Barrel in Sacramento recently closed its doors for good.\r\nA post on Reddit shows what appear to be construction workers boarding up the Howe Avenue location on Monday, wh… [+892 chars]'}]}

# %% [markdown]
# # Load data into MongoDB

# %%
from pymongo import MongoClient
client = MongoClient('localhost',27017)
db = client.proj5400
collection_articles = db.articles_data 
collection_restaurants = db.restaurants_data

# %%
# Insert articles data into MongoDB
if articles:
    collection_articles.insert_many(articles)
else:
    print("No data to insert.")

# %%
# Insert restaurants data into MongoDB
restaurants_dict = restaurants_cleaned.to_dict('records')
collection_restaurants.insert_many(restaurants_dict)
# Out:
# InsertManyResult([ObjectId('662152e9485ce7a81bfe4b3f'), ObjectId('662152e9485ce7a81bfe4b40'), ObjectId('662152e9485ce7a81bfe4b41'), ObjectId('662152e9485ce7a81bfe4b42'), ObjectId('662152e9485ce7a81bfe4b43'), ObjectId('662152e9485ce7a81bfe4b44'), ObjectId('662152e9485ce7a81bfe4b45'), ObjectId('662152e9485ce7a81bfe4b46'), ObjectId('662152e9485ce7a81bfe4b47'), ObjectId('662152e9485ce7a81bfe4b48'), ObjectId('662152e9485ce7a81bfe4b49'), ObjectId('662152e9485ce7a81bfe4b4a'), ObjectId('662152e9485ce7a81bfe4b4b'), ObjectId('662152e9485ce7a81bfe4b4c'), ObjectId('662152e9485ce7a81bfe4b4d'), ObjectId('662152e9485ce7a81bfe4b4e'), ObjectId('662152e9485ce7a81bfe4b4f'), ObjectId('662152e9485ce7a81bfe4b50'), ObjectId('662152e9485ce7a81bfe4b51'), ObjectId('662152e9485ce7a81bfe4b52'), ObjectId('662152e9485ce7a81bfe4b53'), ObjectId('662152e9485ce7a81bfe4b54'), ObjectId('662152e9485ce7a81bfe4b55'), ObjectId('662152e9485ce7a81bfe4b56'), ObjectId('662152e9485ce7a81bfe4b57'), ObjectId('662152e9485ce7a81bfe4b58'), ObjectId('662152e9485ce7a81bfe4b59'), ObjectId('662152e9485ce7a81bfe4b5a'), ObjectId('662152e9485ce7a81bfe4b5b'), ObjectId('662152e9485ce7a81bfe4b5c'), ObjectId('662152e9485ce7a81bfe4b5d'), ObjectId('662152e9485ce7a81bfe4b5e'), ObjectId('662152e9485ce7a81bfe4b5f'), ObjectId('662152e9485ce7a81bfe4b60'), ObjectId('662152e9485ce7a81bfe4b61'), ObjectId('662152e9485ce7a81bfe4b62'), ObjectId('662152e9485ce7a81bfe4b63'), ObjectId('662152e9485ce7a81bfe4b64'), ObjectId('662152e9485ce7a81bfe4b65'), ObjectId('662152e9485ce7a81bfe4b66'), ObjectId('662152e9485ce7a81bfe4b67'), ObjectId('662152e9485ce7a81bfe4b68'), ObjectId('662152e9485ce7a81bfe4b69'), ObjectId('662152e9485ce7a81bfe4b6a'), ObjectId('662152e9485ce7a81bfe4b6b'), ObjectId('662152e9485ce7a81bfe4b6c'), ObjectId('662152e9485ce7a81bfe4b6d'), ObjectId('662152e9485ce7a81bfe4b6e'), ObjectId('662152e9485ce7a81bfe4b6f'), ObjectId('662152e9485ce7a81bfe4b70'), ObjectId('662152e9485ce7a81bfe4b71'), ObjectId('662152e9485ce7a81bfe4b72'), ObjectId('662152e9485ce7a81bfe4b73'), ObjectId('662152e9485ce7a81bfe4b74'), ObjectId('662152e9485ce7a81bfe4b75'), ObjectId('662152e9485ce7a81bfe4b76'), ObjectId('662152e9485ce7a81bfe4b77'), ObjectId('662152e9485ce7a81bfe4b78'), ObjectId('662152e9485ce7a81bfe4b79'), ObjectId('662152e9485ce7a81bfe4b7a'), ObjectId('662152e9485ce7a81bfe4b7b'), ObjectId('662152e9485ce7a81bfe4b7c'), ObjectId('662152e9485ce7a81bfe4b7d'), ObjectId('662152e9485ce7a81bfe4b7e'), ObjectId('662152e9485ce7a81bfe4b7f'), ObjectId('662152e9485ce7a81bfe4b80'), ObjectId('662152e9485ce7a81bfe4b81'), ObjectId('662152e9485ce7a81bfe4b82'), ObjectId('662152e9485ce7a81bfe4b83'), ObjectId('662152e9485ce7a81bfe4b84'), ObjectId('662152e9485ce7a81bfe4b85'), ObjectId('662152e9485ce7a81bfe4b86'), ObjectId('662152e9485ce7a81bfe4b87'), ObjectId('662152e9485ce7a81bfe4b88'), ObjectId('662152e9485ce7a81bfe4b89'), ObjectId('662152e9485ce7a81bfe4b8a'), ObjectId('662152e9485ce7a81bfe4b8b'), ObjectId('662152e9485ce7a81bfe4b8c'), ObjectId('662152e9485ce7a81bfe4b8d'), ObjectId('662152e9485ce7a81bfe4b8e'), ObjectId('662152e9485ce7a81bfe4b8f'), ObjectId('662152e9485ce7a81bfe4b90'), ObjectId('662152e9485ce7a81bfe4b91'), ObjectId('662152e9485ce7a81bfe4b92'), ObjectId('662152e9485ce7a81bfe4b93'), ObjectId('662152e9485ce7a81bfe4b94'), ObjectId('662152e9485ce7a81bfe4b95'), ObjectId('662152e9485ce7a81bfe4b96'), ObjectId('662152e9485ce7a81bfe4b97'), ObjectId('662152e9485ce7a81bfe4b98'), ObjectId('662152e9485ce7a81bfe4b99'), ObjectId('662152e9485ce7a81bfe4b9a'), ObjectId('662152e9485ce7a81bfe4b9b'), ObjectId('662152e9485ce7a81bfe4b9c'), ObjectId('662152e9485ce7a81bfe4b9d'), ObjectId('662152e9485ce7a81bfe4b9e'), ObjectId('662152e9485ce7a81bfe4b9f'), ObjectId('662152e9485ce7a81bfe4ba0'), ObjectId('662152e9485ce7a81bfe4ba1'), ObjectId('662152e9485ce7a81bfe4ba2'), ObjectId('662152e9485ce7a81bfe4ba3'), ObjectId('662152e9485ce7a81bfe4ba4'), ObjectId('662152e9485ce7a81bfe4ba5'), ObjectId('662152e9485ce7a81bfe4ba6'), ObjectId('662152e9485ce7a81bfe ...

# %% [markdown]
# # Flask input and output

# %%
from flask import Flask, request, render_template
app = Flask("Interactive App")

@app.route('/', methods=['GET'])
def my_form():
    return render_template("search_form.html")

@app.route('/', methods=['POST'])
def search_articles():
    search_term = request.form['search_term']
    filter_term = request.form['filter_term']  

    article_query = {
        '$or': [
            {'title': {'$regex': search_term, '$options': 'i'}},
            {'description': {'$regex': search_term, '$options': 'i'}},
            {'content': {'$regex': search_term, '$options': 'i'}}
        ]
    }
    results = collection_articles.find(article_query)
    articles = list(results)
    
    restaurant_query = {
        '$and':[
            {'cuisine_description': {'$regex': search_term}},
            {'zipcode': {'$regex': filter_term}}
        ]
    }
    results2 = collection_restaurants.find(restaurant_query)
    restaurants = list(results2)
    
    return render_template('results.html', articles=articles, restaurants=restaurants)

# %%
app.run(host='localhost', port=5002)
# Out:
#  * Serving Flask app 'Interactive App'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5002
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 13:06:00] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 13:06:38] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 13:06:41] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 15:41:24] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 15:42:03] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 15:42:16] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:00:43] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:00:48] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:00:52] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:01:00] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:01:03] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:01:09] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:01:18] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:01:23] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:01:38] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [18/Apr/2024 16:01:42] "GET / HTTP/1.1" 200 -
