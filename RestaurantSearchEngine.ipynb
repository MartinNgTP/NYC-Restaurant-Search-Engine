# %% [markdown]
# Data Source:
# * NYC Open Data API for restaurants data
# * https://dev.socrata.com/foundry/data.cityofnewyork.us/43nn-pn8j
# * NewsAPI for articles (json files)
# * https://newsapi.org/
#
# Technologies:
# 1. **Request API** from NewsAPI to get "food" related articles & NYC Open Data API for restaurants data
# 2. Store articles data and restaurants data in **MongoDB**
# 3. **Flask** to get user input cuisine and zipcode, output restaurants and articles.
#
# Cannot be run on Google Collab because localhost

# %% [markdown]
# # NYC Restaurants data

# %% [markdown]
# Import data from Socrata Open Data API, give it a minute to load.

# %%
#pip install sodapy

# %%
# Ignore warning
from sodapy import Socrata
import pandas as pd

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("43nn-pn8j", limit=300000)

# Convert to pandas DataFrame
restaurants = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# ### Clean data

# %% [markdown]
# * Columns dba(restaurant name), cuisine_description, and zipcode contain missing values
# * Lowercase cuisine_description for easier search
# * Duplicate restaurant records, drop duplicates

# %%
# Ignore warning
columns_to_check = ['dba', 'cuisine_description', 'zipcode']
df = restaurants.dropna(subset=columns_to_check)

df['zipcode'] = df['zipcode'].astype(int).astype(str)
df.loc[:,'cuisine_description'] = df['cuisine_description'].str.lower()

restaurants_cleaned = df.drop_duplicates(subset=['dba'], keep='first')  #Keeps only the first occurrence
# Out:
# /var/folders/pf/pdyz_nzx4mz21xl07fjfgymh0000gn/T/ipykernel_25726/2950411719.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['zipcode'] = df['zipcode'].astype(int).astype(str)

# %% [markdown]
# # Articles:

# %% [markdown]
# Since this API permits request as far back as one month ago, calculate date of one month ago

# %%
#pip install python-dateutil

# %%
import datetime
from dateutil.relativedelta import relativedelta

# Get one month ago's date
today_date = datetime.date.today()
one_month_ago = today_date - relativedelta(months=1)
one_month_ago_str = one_month_ago.strftime('%Y-%m-%d')

# %%
import requests

# Keywords for now: dining, cuisine, restaurant, recipe. 
# Add more or modify to improve search results.
url = (
    f'https://newsapi.org/v2/everything?'
    f'q=(dining OR cuisine OR restaurant OR recipe)&'
    f'from={one_month_ago_str}&'
       'apiKey=7152e173864048d6934a8df325418c66')

response = requests.get(url)
data = response.json()
articles = data.get('articles', [])

# %% [markdown]
# # Load data into MongoDB

# %%
from pymongo import MongoClient
client = MongoClient('localhost',27017)
db = client.proj5400
collection_articles = db.articles_data 
collection_restaurants = db.restaurants_data

# %%
# Insert articles data into MongoDB
if articles:
    collection_articles.insert_many(articles)
else:
    print("No data to insert.")

# %%
# Insert restaurants data into MongoDB
restaurants_dict = restaurants_cleaned.to_dict('records')
collection_restaurants.insert_many(restaurants_dict)
# Out:
# InsertManyResult([ObjectId('672a7aea5a6fbd2cafc6de6d'), ObjectId('672a7aea5a6fbd2cafc6de6e'), ObjectId('672a7aea5a6fbd2cafc6de6f'), ObjectId('672a7aea5a6fbd2cafc6de70'), ObjectId('672a7aea5a6fbd2cafc6de71'), ObjectId('672a7aea5a6fbd2cafc6de72'), ObjectId('672a7aea5a6fbd2cafc6de73'), ObjectId('672a7aea5a6fbd2cafc6de74'), ObjectId('672a7aea5a6fbd2cafc6de75'), ObjectId('672a7aea5a6fbd2cafc6de76'), ObjectId('672a7aea5a6fbd2cafc6de77'), ObjectId('672a7aea5a6fbd2cafc6de78'), ObjectId('672a7aea5a6fbd2cafc6de79'), ObjectId('672a7aea5a6fbd2cafc6de7a'), ObjectId('672a7aea5a6fbd2cafc6de7b'), ObjectId('672a7aea5a6fbd2cafc6de7c'), ObjectId('672a7aea5a6fbd2cafc6de7d'), ObjectId('672a7aea5a6fbd2cafc6de7e'), ObjectId('672a7aea5a6fbd2cafc6de7f'), ObjectId('672a7aea5a6fbd2cafc6de80'), ObjectId('672a7aea5a6fbd2cafc6de81'), ObjectId('672a7aea5a6fbd2cafc6de82'), ObjectId('672a7aea5a6fbd2cafc6de83'), ObjectId('672a7aea5a6fbd2cafc6de84'), ObjectId('672a7aea5a6fbd2cafc6de85'), ObjectId('672a7aea5a6fbd2cafc6de86'), ObjectId('672a7aea5a6fbd2cafc6de87'), ObjectId('672a7aea5a6fbd2cafc6de88'), ObjectId('672a7aea5a6fbd2cafc6de89'), ObjectId('672a7aea5a6fbd2cafc6de8a'), ObjectId('672a7aea5a6fbd2cafc6de8b'), ObjectId('672a7aea5a6fbd2cafc6de8c'), ObjectId('672a7aea5a6fbd2cafc6de8d'), ObjectId('672a7aea5a6fbd2cafc6de8e'), ObjectId('672a7aea5a6fbd2cafc6de8f'), ObjectId('672a7aea5a6fbd2cafc6de90'), ObjectId('672a7aea5a6fbd2cafc6de91'), ObjectId('672a7aea5a6fbd2cafc6de92'), ObjectId('672a7aea5a6fbd2cafc6de93'), ObjectId('672a7aea5a6fbd2cafc6de94'), ObjectId('672a7aea5a6fbd2cafc6de95'), ObjectId('672a7aea5a6fbd2cafc6de96'), ObjectId('672a7aea5a6fbd2cafc6de97'), ObjectId('672a7aea5a6fbd2cafc6de98'), ObjectId('672a7aea5a6fbd2cafc6de99'), ObjectId('672a7aea5a6fbd2cafc6de9a'), ObjectId('672a7aea5a6fbd2cafc6de9b'), ObjectId('672a7aea5a6fbd2cafc6de9c'), ObjectId('672a7aea5a6fbd2cafc6de9d'), ObjectId('672a7aea5a6fbd2cafc6de9e'), ObjectId('672a7aea5a6fbd2cafc6de9f'), ObjectId('672a7aea5a6fbd2cafc6dea0'), ObjectId('672a7aea5a6fbd2cafc6dea1'), ObjectId('672a7aea5a6fbd2cafc6dea2'), ObjectId('672a7aea5a6fbd2cafc6dea3'), ObjectId('672a7aea5a6fbd2cafc6dea4'), ObjectId('672a7aea5a6fbd2cafc6dea5'), ObjectId('672a7aea5a6fbd2cafc6dea6'), ObjectId('672a7aea5a6fbd2cafc6dea7'), ObjectId('672a7aea5a6fbd2cafc6dea8'), ObjectId('672a7aea5a6fbd2cafc6dea9'), ObjectId('672a7aea5a6fbd2cafc6deaa'), ObjectId('672a7aea5a6fbd2cafc6deab'), ObjectId('672a7aea5a6fbd2cafc6deac'), ObjectId('672a7aea5a6fbd2cafc6dead'), ObjectId('672a7aea5a6fbd2cafc6deae'), ObjectId('672a7aea5a6fbd2cafc6deaf'), ObjectId('672a7aea5a6fbd2cafc6deb0'), ObjectId('672a7aea5a6fbd2cafc6deb1'), ObjectId('672a7aea5a6fbd2cafc6deb2'), ObjectId('672a7aea5a6fbd2cafc6deb3'), ObjectId('672a7aea5a6fbd2cafc6deb4'), ObjectId('672a7aea5a6fbd2cafc6deb5'), ObjectId('672a7aea5a6fbd2cafc6deb6'), ObjectId('672a7aea5a6fbd2cafc6deb7'), ObjectId('672a7aea5a6fbd2cafc6deb8'), ObjectId('672a7aea5a6fbd2cafc6deb9'), ObjectId('672a7aea5a6fbd2cafc6deba'), ObjectId('672a7aea5a6fbd2cafc6debb'), ObjectId('672a7aea5a6fbd2cafc6debc'), ObjectId('672a7aea5a6fbd2cafc6debd'), ObjectId('672a7aea5a6fbd2cafc6debe'), ObjectId('672a7aea5a6fbd2cafc6debf'), ObjectId('672a7aea5a6fbd2cafc6dec0'), ObjectId('672a7aea5a6fbd2cafc6dec1'), ObjectId('672a7aea5a6fbd2cafc6dec2'), ObjectId('672a7aea5a6fbd2cafc6dec3'), ObjectId('672a7aea5a6fbd2cafc6dec4'), ObjectId('672a7aea5a6fbd2cafc6dec5'), ObjectId('672a7aea5a6fbd2cafc6dec6'), ObjectId('672a7aea5a6fbd2cafc6dec7'), ObjectId('672a7aea5a6fbd2cafc6dec8'), ObjectId('672a7aea5a6fbd2cafc6dec9'), ObjectId('672a7aea5a6fbd2cafc6deca'), ObjectId('672a7aea5a6fbd2cafc6decb'), ObjectId('672a7aea5a6fbd2cafc6decc'), ObjectId('672a7aea5a6fbd2cafc6decd'), ObjectId('672a7aea5a6fbd2cafc6dece'), ObjectId('672a7aea5a6fbd2cafc6decf'), ObjectId('672a7aea5a6fbd2cafc6ded0'), ObjectId('672a7aea5a6fbd2cafc6ded1'), ObjectId('672a7aea5a6fbd2cafc6ded2'), ObjectId('672a7aea5a6fbd2cafc6ded3'), ObjectId('672a7aea5a6fbd2cafc6ded4'), ObjectId('672a7aea5a6fbd2cafc6 ...

# %% [markdown]
# # Flask input and output

# %%
from flask import Flask, request, render_template
app = Flask("Interactive App")

@app.route('/', methods=['GET'])
def my_form():
    return render_template("search_form.html")

@app.route('/', methods=['POST'])
def search_articles():
    search_term = request.form['search_term']
    filter_term = request.form['filter_term']  

    article_query = {
        '$or': [
            {'title': {'$regex': search_term, '$options': 'i'}},
            {'description': {'$regex': search_term, '$options': 'i'}},
            {'content': {'$regex': search_term, '$options': 'i'}}
        ]
    }
    results = collection_articles.find(article_query)
    articles = list(results)
    
    restaurant_query = {
        '$and':[
            {'cuisine_description': {'$regex': search_term}},
            {'zipcode': {'$regex': filter_term}}
        ]
    }
    results2 = collection_restaurants.find(restaurant_query)
    restaurants = list(results2)
    
    return render_template('results.html', articles=articles, restaurants=restaurants)

# %%
app.run(host='localhost', port=5002)
# Out:
#  * Serving Flask app 'Interactive App'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5002
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [05/Nov/2024 15:07:18] "GET / HTTP/1.1" 200 -
